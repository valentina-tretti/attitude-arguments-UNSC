# %% [markdown]
# # Task 3- Premise-Claim Relation Extraction and Validation

# %% [markdown]
# ## Requirements

# %%
import pandas as pd
import torch
from sentence_transformers import SentenceTransformer, util
from sklearn.metrics import classification_report

# %% [markdown]
# ## Loading Data

# %%
# Data Loading
df = pd.read_excel("/content/Task2_results_Debate_7138.xlsx")

# %%
# Dropping unnecessary columns
df= df.drop(['label', 'Attitude Fragment', 'Predicted Argument or Not', 'Predicted Argument', 'Predicted_Labels'], axis=1)
df
# Out:
#                                              File_name  \
# 0    UNSC_2014_SPV.7138_spch020_sentsplit_Russian_F...
# 1    UNSC_2014_SPV.7138_spch020_sentsplit_Russian_F...
# 2    UNSC_2014_SPV.7138_spch020_sentsplit_Russian_F...
# 3    UNSC_2014_SPV.7138_spch020_sentsplit_Russian_F...
# 4    UNSC_2014_SPV.7138_spch020_sentsplit_Russian_F...
# ..                                                 ...
# 310       UNSC_2014_SPV.7138_spch014_sentsplit_Nigeria
# 311       UNSC_2014_SPV.7138_spch014_sentsplit_Nigeria
# 312       UNSC_2014_SPV.7138_spch014_sentsplit_Nigeria
# 313       UNSC_2014_SPV.7138_spch014_sentsplit_Nigeria
# 314       UNSC_2014_SPV.7138_spch014_sentsplit_Nigeria
#
#                                                 Speech  \
# 0    Some colleagues today have achieved high level...
# 1    I must mention that the Ukrainian colleague ne...
# 2    Ifone is to speak ofblood, indeed the blood is...
# 3    Colleagues that have taken the floor discussed...
# 4    I will not comment on everything heard today -...
# ..                                                 ...
# 310  Our willing submission to the rule of the Inte...
# 311  Nigeria is vehemently opposed to unilateral se...
# 312  Standing on that fundamental principle, Nigeri...
# 313  It is therefore needless to restate that the i...
# 314  The consequences of any defiance are better im...
#
#     claim_premise_predictions
# 0                     Premise
# 1                       Claim
# 2                     Premise
# 3                     Premise
# 4                       Claim
# ..                        ...
# 310                     Claim
# 311                     Claim
# 312                     Claim
# 313                     Claim
# 314                     Claim
#
# [315 rows x 3 columns]

# %%
# Grouping by File_name to compare within the same document
grouped = df.groupby("File_name")

# %% [markdown]
# ## Loading Multi-QA Sentence Transformer Model

# %%
# Load sentence transformer model
model = SentenceTransformer('sentence-transformers/multi-qa-mpnet-base-dot-v1')
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/212 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/8.71k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Extracting relations based on similarity scores with Sentence Transformer
relations_2 = []

for file_name, group in grouped:
    premises = group[group["claim_premise_predictions"] == "Premise"]
    claims = group[group["claim_premise_predictions"] == "Claim"]

    if premises.empty or claims.empty:
        continue  # Skip if no premises or claims

    # Encode sentences using SBERT
    premise_embeddings = model.encode(premises["Speech"].tolist(), convert_to_tensor=True)
    claim_embeddings = model.encode(claims["Speech"].tolist(), convert_to_tensor=True)

    # Compute cosine similarity between each premise and claim
    similarity_matrix = util.pytorch_cos_sim(premise_embeddings, claim_embeddings)

    # Determine relations
    for i, premise_text in enumerate(premises["Speech"]):
        for j, claim_text in enumerate(claims["Speech"]):
            similarity = similarity_matrix[i][j].item()  # Get similarity score

            relation_type = "support" if similarity > 0.5 else "attack"
            relations_2.append((file_name, premise_text, claim_text, similarity, relation_type))

# Convert to DataFrame
relations_df_model = pd.DataFrame(relations_2, columns=["File_name", "Premise", "Claim", "Similarity", "Relation"])

# %%
relations_df_model
# Out:
#                                               File_name  \
# 0     UNSC_2014_SPV.7138_spch002_sentsplit_Russian_F...
# 1     UNSC_2014_SPV.7138_spch002_sentsplit_Russian_F...
# 2     UNSC_2014_SPV.7138_spch002_sentsplit_Russian_F...
# 3     UNSC_2014_SPV.7138_spch002_sentsplit_Russian_F...
# 4     UNSC_2014_SPV.7138_spch002_sentsplit_Russian_F...
# ...                                                 ...
# 1667  UNSC_2014_SPV.7138_spch020_sentsplit_Russian_F...
# 1668  UNSC_2014_SPV.7138_spch020_sentsplit_Russian_F...
# 1669  UNSC_2014_SPV.7138_spch020_sentsplit_Russian_F...
# 1670  UNSC_2014_SPV.7138_spch020_sentsplit_Russian_F...
# 1671  UNSC_2014_SPV.7138_spch020_sentsplit_Russian_F...
#
#                                                 Premise  \
# 0     That principle is confirmed in the 1970 Declar...
# 1     That principle is confirmed in the 1970 Declar...
# 2     That principle is confirmed in the 1970 Declar...
# 3     That principle is confirmed in the 1970 Declar...
# 4     That principle is confirmed in the 1970 Declar...
# ...                                                 ...
# 1667  To conclude, one of our colleagues said that K...
# 1668  To conclude, one of our colleagues said that K...
# 1669  To conclude, one of our colleagues said that K...
# 1670  To conclude, one of our colleagues said that K...
# 1671  To conclude, one of our colleagues said that K...
#
#                                                   Claim  Similarity Relation
# 0     Many times, we have put forth in this Chamber ...    0.300350   attack
# 1     That general context is important to understan...    0.419197   attack
# 2     It is a secret to no one that the Russian Fede...    0.351075   attack
# 3     We cannot go along with its basic assumption, ...    0.336189   attack
# 4     The philosophy of the sponsors of the draft re...    0.550103  support
# ...                                                 ...         ...      ...
# 1667  That does not apply to us; it is a phrase take...    0.413647   attack
# 1668                          Ms. Power spoke of truth.    0.361243   attack
# 1669  The world would be very interested to know if ...    0.513300  support
# 1670  But the problem is not with Moscow; it has to ...    0.667055  support
# 1671  Nevertheless, we would appeal to all to put an...    0.655442  support
#
# [1672 rows x 5 columns]

# %%
# Saving Similarity scores obtained with Sentence Transformer
relations_df_model.to_excel("Task3_Sent_Transformer_Multi-Qa_results.xlsx", index=False)

# %% [markdown]
# ## Predicting similarity scores over UNSCUkrArg Dataset

# %%
data_unsc_annotated = pd.read_excel("/content/Task3 file evaluations UNSC speeches.xlsx")
data_unsc_annotated
# Out:
#                                               filename  \
# 0    UNSC_2014_SPV.7165_spch016_sentsplit_Lithuania...
# 1    UNSC_2014_SPV.7165_spch016_sentsplit_Lithuania...
# 2    UNSC_2014_SPV.7165_spch016_sentsplit_Lithuania...
# 3    UNSC_2014_SPV.7165_spch016_sentsplit_Lithuania...
# 4    UNSC_2014_SPV.7165_spch016_sentsplit_Lithuania...
# ..                                                 ...
# 803  UNSC_2014_SPV.7154_spch021_sentsplit_Russian_F...
# 804  UNSC_2014_SPV.7154_spch021_sentsplit_Russian_F...
# 805     UNSC_2014_SPV.7154_spch012_sentsplit_China.txt
# 806     UNSC_2014_SPV.7154_spch012_sentsplit_China.txt
# 807     UNSC_2014_SPV.7154_spch012_sentsplit_China.txt
#
#                                                Premise  \
# 0    adding to the growing list of breaches of Russ...
# 1    Barricades in Maidan Square are being dismantled.
# 2    I recall my French colleague referring a numbe...
# 3    Users of those will see that there is a signif...
# 4                     barricades are being dismantled.
# ..                                                 ...
# 803  That would have extremely significant conseque...
# 804  That would have extremely significant conseque...
# 805  Settling the question of Ukraine involves the ...
# 806  in order to narrow differences and settle the ...
# 807  in order to narrow differences and settle the ...
#
#                                                  Claim Relation
# 0    the Geneva statement is just another document ...  support
# 1    Despite growing provocations, the Ukrainian au...  support
# 2    Despite growing provocations, the Ukrainian au...  support
# 3    Despite growing provocations, the Ukrainian au...  support
# 4    Despite growing provocations, the Ukrainian au...  support
# ..                                                 ...      ...
# 803  Let us ensure that we do not permit the Ukrain...  support
# 804                          That needs to be avoided.  support
# 805      It should be considered in a balanced manner.  support
# 806  Political and diplomatic channels should conti...  support
# 807  China has consistently called on the internati...  support
#
# [808 rows x 4 columns]

# %%
# Encode premises and claims using SBERT
premise_embeddings = model_2.encode(data_unsc_annotated["Premise"].tolist(), convert_to_tensor=True)
claim_embeddings = model_2.encode(data_unsc_annotated["Claim"].tolist(), convert_to_tensor=True)

# Compute cosine similarity between Premise-Claim pairs
similarity_scores = util.pytorch_cos_sim(premise_embeddings, claim_embeddings).diagonal().tolist()

# Classify relations based on similarity threshold
data_unsc_annotated["Predicted_Relation"] = ["support" if sim > 0.5 else "attack" for sim in similarity_scores]
data_unsc_annotated["Similarity"] = similarity_scores  # Store similarity for analysis

# Evaluate against gold standard Relation column
print(classification_report(data_unsc_annotated["Relation"].str.lower(), data_unsc_annotated["Predicted_Relation"], digits=4))
# Out:
#               precision    recall  f1-score   support
#
#       attack     0.0000    0.0000    0.0000         0
#      support     1.0000    0.4394    0.6105       808
#
#     accuracy                         0.4394       808
#    macro avg     0.5000    0.2197    0.3052       808
# weighted avg     1.0000    0.4394    0.6105       808
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
data_unsc_annotated.to_excel("predicted_relations_unscannotations_senttransformer.xlsx")
